# %% [markdown]
# ## Air Quality Forecast : Machine Learning Model

# %%
import numpy as np 
import pandas as pd  
import matplotlib.pyplot as plt  
import seaborn as sns  
import datetime 
from warnings import filterwarnings
filterwarnings('ignore')

from sklearn.preprocessing import LabelEncoder 
from sklearn.model_selection import train_test_split  
from sklearn.linear_model import LinearRegression  
from sklearn.tree import DecisionTreeRegressor 
from sklearn.ensemble import RandomForestRegressor  
from sklearn import metrics  
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score  
from sklearn.metrics import accuracy_score, confusion_matrix 
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Reading and exploring the Air Quality Forecast Dataset

# %%
df = pd.read_csv('air quality data.csv')

# %% [markdown]
# ## Analysing the dataset

# %%
df.head()
# Out:
#         City  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2      O3  \
# 0  Ahmedabad    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64  133.36
# 1  Ahmedabad    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55   34.06
# 2  Ahmedabad    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07   30.70
# 3  Ahmedabad    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59   36.08
# 4  Ahmedabad    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33   39.31
#
#    Benzene  Toluene  Xylene  AQI
# 0     0.00     0.02    0.00  NaN
# 1     3.68     5.50    3.77  NaN
# 2     6.80    16.40    2.25  NaN
# 3     4.43    10.14    1.00  NaN
# 4     7.01    18.89    2.78  NaN

# %%
df.head(10)
# Out:
#         City  PM2.5  PM10      NO    NO2     NOx  NH3      CO    SO2      O3  \
# 0  Ahmedabad    NaN   NaN    0.92  18.22   17.15  NaN    0.92  27.64  133.36
# 1  Ahmedabad    NaN   NaN    0.97  15.69   16.46  NaN    0.97  24.55   34.06
# 2  Ahmedabad    NaN   NaN   17.40  19.30   29.70  NaN   17.40  29.07   30.70
# 3  Ahmedabad    NaN   NaN    1.70  18.48   17.97  NaN    1.70  18.59   36.08
# 4  Ahmedabad    NaN   NaN   22.10  21.42   37.76  NaN   22.10  39.33   39.31
# 5  Ahmedabad    NaN   NaN   45.41  38.48   81.50  NaN   45.41  45.76   46.51
# 6  Ahmedabad    NaN   NaN  112.16  40.62  130.77  NaN  112.16  32.28   33.47
# 7  Ahmedabad    NaN   NaN   80.87  36.74   96.75  NaN   80.87  38.54   31.89
# 8  Ahmedabad    NaN   NaN   29.16  31.00   48.00  NaN   29.16  58.68   25.75
# 9  Ahmedabad    NaN   NaN     NaN   7.04    0.00  NaN     NaN   8.29    4.55
#
#    Benzene  Toluene  Xylene  AQI
# 0     0.00     0.02    0.00  NaN
# 1     3.68     5.50    3.77  NaN
# 2     6.80    16.40    2.25  NaN
# 3     4.43    10.14    1.00  NaN
# 4     7.01    18.89    2.78  NaN
# 5     5.42    10.83    1.93  NaN
# 6     0.00     0.00    0.00  NaN
# 7     0.00     0.00    0.00  NaN
# 8     0.00     0.00    0.00  NaN
# 9     0.00     0.00    0.00  NaN

# %%
df.tail()
# Out:
#                 City  PM2.5   PM10    NO    NO2    NOx    NH3    CO    SO2  \
# 29526  Visakhapatnam  15.02  50.94  7.68  25.06  19.54  12.47  0.47   8.55
# 29527  Visakhapatnam  24.38  74.09  3.42  26.06  16.53  11.99  0.52  12.72
# 29528  Visakhapatnam  22.91  65.73  3.45  29.53  18.33  10.71  0.48   8.42
# 29529  Visakhapatnam  16.64  49.97  4.05  29.26  18.80  10.03  0.52   9.84
# 29530  Visakhapatnam  15.00  66.00  0.40  26.85  14.05   5.20  0.59   2.10
#
#           O3  Benzene  Toluene  Xylene   AQI
# 29526  23.30     2.24    12.07    0.73  41.0
# 29527  30.14     0.74     2.21    0.38  70.0
# 29528  30.96     0.01     0.01    0.00  68.0
# 29529  28.30     0.00     0.00    0.00  54.0
# 29530  17.05      NaN      NaN     NaN  50.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   City     29531 non-null  object
#  1   PM2.5    24933 non-null  float64
#  2   PM10     18391 non-null  float64
#  3   NO       25949 non-null  float64
#  4   NO2      25946 non-null  float64
#  5   NOx      25346 non-null  float64
#  6   NH3      19203 non-null  float64
#  7   CO       27472 non-null  float64
#  8   SO2      25677 non-null  float64
#  9   O3       25509 non-null  float64
#  10  Benzene  23908 non-null  float64
#  11  Toluene  21490 non-null  float64
#  12  Xylene   11422 non-null  float64
#  13  AQI      24850 non-null  float64
# dtypes: float64(13), object(1)
# memory usage: 3.2+ MB

# %%
df.describe()
# Out:
#               PM2.5          PM10            NO           NO2           NOx  \
# count  24933.000000  18391.000000  25949.000000  25946.000000  25346.000000
# mean      67.450578    118.127103     17.574730     28.560659     32.309123
# std       64.661449     90.605110     22.785846     24.474746     31.646011
# min        0.040000      0.010000      0.020000      0.010000      0.000000
# 25%       28.820000     56.255000      5.630000     11.750000     12.820000
# 50%       48.570000     95.680000      9.890000     21.690000     23.520000
# 75%       80.590000    149.745000     19.950000     37.620000     40.127500
# max      949.990000   1000.000000    390.680000    362.210000    467.630000
#
#                 NH3            CO           SO2            O3       Benzene  \
# count  19203.000000  27472.000000  25677.000000  25509.000000  23908.000000
# mean      23.483476      2.248598     14.531977     34.491430      3.280840
# std       25.684275      6.962884     18.133775     21.694928     15.811136
# min        0.010000      0.000000      0.010000      0.010000      0.000000
# 25%        8.580000      0.510000      5.670000     18.860000      0.120000
# 50%       15.850000      0.890000      9.160000     30.840000      1.070000
# 75%       30.020000      1.450000     15.220000     45.570000      3.080000
# max      352.890000    175.810000    193.860000    257.730000    455.030000
#
#             Toluene        Xylene           AQI
# count  21490.000000  11422.000000  24850.000000
# mean       8.700972      3.070128    166.463581
# std       19.969164      6.323247    140.696585
# min        0.000000      0.000000     13.000000
# 25%        0.600000      0.140000     81.000000
# 50%        2.970000      0.980000    118.000000
# 75%        9.150000      3.350000    208.000000
# max      454.850000    170.370000   2049.000000

# %%
df.describe().T #Transpose
# Out:
#            count        mean         std    min     25%     50%       75%  \
# PM2.5    24933.0   67.450578   64.661449   0.04  28.820   48.57   80.5900
# PM10     18391.0  118.127103   90.605110   0.01  56.255   95.68  149.7450
# NO       25949.0   17.574730   22.785846   0.02   5.630    9.89   19.9500
# NO2      25946.0   28.560659   24.474746   0.01  11.750   21.69   37.6200
# NOx      25346.0   32.309123   31.646011   0.00  12.820   23.52   40.1275
# NH3      19203.0   23.483476   25.684275   0.01   8.580   15.85   30.0200
# CO       27472.0    2.248598    6.962884   0.00   0.510    0.89    1.4500
# SO2      25677.0   14.531977   18.133775   0.01   5.670    9.16   15.2200
# O3       25509.0   34.491430   21.694928   0.01  18.860   30.84   45.5700
# Benzene  23908.0    3.280840   15.811136   0.00   0.120    1.07    3.0800
# Toluene  21490.0    8.700972   19.969164   0.00   0.600    2.97    9.1500
# Xylene   11422.0    3.070128    6.323247   0.00   0.140    0.98    3.3500
# AQI      24850.0  166.463581  140.696585  13.00  81.000  118.00  208.0000
#
#              max
# PM2.5     949.99
# PM10     1000.00
# NO        390.68
# NO2       362.21
# NOx       467.63
# NH3       352.89
# CO        175.81
# SO2       193.86
# O3        257.73
# Benzene   455.03
# Toluene   454.85
# Xylene    170.37
# AQI      2049.00

# %%
df.columns
# Out:
# Index(['City', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3',
#        'Benzene', 'Toluene', 'Xylene', 'AQI'],
#       dtype='object')

# %%
df.shape
# Out:
# (29531, 14)

# %%
df.isnull().sum()
# Out:
# City           0
# PM2.5       4598
# PM10       11140
# NO          3582
# NO2         3585
# NOx         4185
# NH3        10328
# CO          2059
# SO2         3854
# O3          4022
# Benzene     5623
# Toluene     8041
# Xylene     18109
# AQI         4681
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 83807

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=29531, step=1),
#  Index(['City', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3',
#         'Benzene', 'Toluene', 'Xylene', 'AQI'],
#        dtype='object')]

# %%
df.duplicated().sum()
# Out:
# 2297

# %%
df1 = df.dropna(subset=['AQI'],inplace=True)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Xylene     15372
# PM10        7086
# NH3         6536
# Toluene     5826
# Benzene     3535
# NOx         1857
# O3           807
# PM2.5        678
# SO2          605
# CO           445
# NO2          391
# NO           387
# City           0
# AQI            0
# dtype: int64

# %%
df.shape
# Out:
# (24850, 14)

# %%
null_values_percentage = (df.isnull().sum()/df.isnull().count()*100).sort_values(ascending=False)

# %%
null_values_percentage
# Out:
# Xylene     61.859155
# PM10       28.515091
# NH3        26.301811
# Toluene    23.444668
# Benzene    14.225352
# NOx         7.472837
# O3          3.247485
# PM2.5       2.728370
# SO2         2.434608
# CO          1.790744
# NO2         1.573441
# NO          1.557344
# City        0.000000
# AQI         0.000000
# dtype: float64

# %%
df['Xylene'].plot(kind='hist',figsize=(10,5))
plt.legend()
plt.show()

# %%
df['PM10'].plot(kind='hist',figsize=(10,5))
plt.legend()
plt.show()

# %%
df['NH3'].plot(kind='hist',figsize=(10,5))
plt.legend()
plt.show()

# %%
df['Toluene'].plot(kind='hist',figsize=(10,5))
plt.legend()
plt.show()

# %%
df['Benzene'].plot(kind='hist',figsize=(10,5))
plt.legend()
plt.show()

# %%
df['NOx'].plot(kind='hist',figsize=(10,5))
plt.legend()
plt.show()

# %%
df['O3'].plot(kind='hist',figsize=(10,5))
plt.legend()
plt.show()

# %%
df['PM2.5'].plot(kind='hist',figsize=(10,5))
plt.legend()
plt.show()

# %%
df['SO2'].plot(kind='hist',figsize=(10,5))
plt.legend()
plt.show()

# %%
df['CO'].plot(kind='hist',figsize=(10,5))
plt.legend()
plt.show()

# %%
df['NO2'].plot(kind='hist',figsize=(10,5))
plt.legend()
plt.show()

# %%
df['NO'].plot(kind='hist',figsize=(10,5))
plt.legend()
plt.show()

# %%
df['AQI'].plot(kind='hist',figsize=(10,5), color='orange')
plt.legend()
plt.show()

# %%
sns.displot(df, x='AQI', color='purple')
plt.show()

# %% [markdown]
# ## Bivariate Analysis

# %%
sns.set(style="darkgrid")
graph=sns.catplot(x="City", kind="count", data=df, height=5, aspect=3, palette="rainbow")
graph.set_xticklabels(rotation=90)

# %%
df.describe().loc["mean"]
# Out:
# PM2.5       67.476613
# PM10       118.454435
# NO          17.622421
# NO2         28.978391
# NOx         32.289012
# NH3         23.848366
# CO           2.345267
# SO2         14.362933
# O3          34.912885
# Benzene      3.458668
# Toluene      9.525714
# Xylene       3.588683
# AQI        166.463581
# Name: mean, dtype: float64

# %%
df = df.replace({
    "PM2.5" : {np.nan:67.476613},
    "PM10" : {np.nan:118.454435},
    "NO" : {np.nan:17.622421},
    "NO2" : {np.nan:28.978391},
    "NOx" : {np.nan:32.289012},
    "NH3" : {np.nan:23.848366},
    "CO" : {np.nan:2.345267},
    "SO2" : {np.nan:14.362933},
    "O3" : {np.nan:34.912885},
    "Benzene" : {np.nan:3.458668},
    "Toluene" : {np.nan:9.525714},
    "Xylene" : {np.nan:3.588683},
    "AQI" : {np.nan:166.463581}})

# %%
df.isnull().sum()
# Out:
# City       0
# PM2.5      0
# PM10       0
# NO         0
# NO2        0
# NOx        0
# NH3        0
# CO         0
# SO2        0
# O3         0
# Benzene    0
# Toluene    0
# Xylene     0
# AQI        0
# dtype: int64

# %%
sns.boxplot(data=df[[ 'PM2.5', 'PM10']], color='green')
# Out:
# <Axes: >

# %%
sns.boxplot(data=df[['City', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3','Benzene', 'Toluene', 'Xylene', 'AQI']], color='green')
# Out:
# <Axes: >

# %%
sns.boxplot(data=df[[ 'CO', 'O3', 'SO2']], color='green')
# Out:
# <Axes: >

# %%
sns.boxplot(data=df[[ 'Benzene', 'Toluene', 'Xylene']], color='green')
# Out:
# <Axes: >

# %% [markdown]
# ## Data Editing Procedures

# %%
#interquartile range
def replace_outliers_with_quartiles(df):
    for column in df.select_dtypes(include=['number']).columns:  
        Q1 = df[column].quantile(0.25)  
        Q3 = df[column].quantile(0.75)  
        IQR = Q3 - Q1  
        
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        
        df[column] = df[column].apply(
            lambda x: Q1 if x < lower_bound else (Q3 if x > upper_bound else x)
        )
    
    return df
df = replace_outliers_with_quartiles(df)

# %%
df['CO'].plot(kind='hist',figsize=(10,5))
plt.legend()
plt.show()

# %%
sns.boxplot(data=df[['City', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3','Benzene', 'Toluene', 'Xylene', 'AQI']])
# Out:
# <Axes: >

# %%
#Distribution of AQI from 2015-2020
sns.displot(df, x="AQI", color="red")
plt.show()

# %%
df1=df.drop(columns=['City'])

# %% [markdown]
# ## Multivariate analysis

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df1.corr(), annot=True)
plt.show()

# %%
df
# Out:
#                 City     PM2.5        PM10     NO    NO2    NOx        NH3  \
# 28         Ahmedabad   83.1300  118.454435   6.93  28.71  33.72  23.848366
# 29         Ahmedabad   79.8400  118.454435  13.85  28.68  41.08  23.848366
# 30         Ahmedabad   94.5200  118.454435  24.39  32.66  52.61  23.848366
# 31         Ahmedabad  135.9900  118.454435  19.71  42.08  38.17  23.848366
# 32         Ahmedabad   79.5075  118.454435  19.71  35.31  72.80  23.848366
# ...              ...       ...         ...    ...    ...    ...        ...
# 29526  Visakhapatnam   15.0200   50.940000   7.68  25.06  19.54  12.470000
# 29527  Visakhapatnam   24.3800   74.090000   3.42  26.06  16.53  11.990000
# 29528  Visakhapatnam   22.9100   65.730000   3.45  29.53  18.33  10.710000
# 29529  Visakhapatnam   16.6400   49.970000   4.05  29.26  18.80  10.030000
# 29530  Visakhapatnam   15.0000   66.000000   0.40  26.85  14.05   5.200000
#
#          CO    SO2       O3   Benzene    Toluene    Xylene    AQI
# 28     1.53  14.89  59.7600  0.020000   0.000000  3.140000  209.0
# 29     1.53  14.89  45.3975  0.040000   0.000000  4.810000  328.0
# 30     1.53  14.89  45.3975  0.240000   0.010000  3.588683  208.0
# 31     1.53  14.89  45.3975  0.400000   0.040000  3.588683  208.0
# 32     1.53  14.89  45.3975  0.460000   0.060000  3.588683  208.0
# ...     ...    ...      ...       ...        ...       ...    ...
# 29526  0.47   8.55  23.3000  2.240000  12.070000  2.650000   41.0
# 29527  0.52  12.72  30.1400  0.740000   2.210000  2.650000   70.0
# 29528  0.48   8.42  30.9600  0.010000   0.010000  2.650000   68.0
# 29529  0.52   9.84  28.3000  0.000000   0.000000  2.650000   54.0
# 29530  0.59   2.10  17.0500  3.458668   9.525714  3.588683   50.0
#
# [24850 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['City', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3',
#        'Benzene', 'Toluene', 'Xylene', 'AQI'],
#       dtype='object')

# %%
df.drop(['City'],axis=1,inplace=True)

# %%
df.head()
# Out:
#        PM2.5        PM10     NO    NO2    NOx        NH3    CO    SO2  \
# 28   83.1300  118.454435   6.93  28.71  33.72  23.848366  1.53  14.89
# 29   79.8400  118.454435  13.85  28.68  41.08  23.848366  1.53  14.89
# 30   94.5200  118.454435  24.39  32.66  52.61  23.848366  1.53  14.89
# 31  135.9900  118.454435  19.71  42.08  38.17  23.848366  1.53  14.89
# 32   79.5075  118.454435  19.71  35.31  72.80  23.848366  1.53  14.89
#
#          O3  Benzene  Toluene    Xylene    AQI
# 28  59.7600     0.02     0.00  3.140000  209.0
# 29  45.3975     0.04     0.00  4.810000  328.0
# 30  45.3975     0.24     0.01  3.588683  208.0
# 31  45.3975     0.40     0.04  3.588683  208.0
# 32  45.3975     0.46     0.06  3.588683  208.0

# %% [markdown]
# ## Data Modelling

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.tree import DecisionTreeRegressor, plot_tree
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
x=df[['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3','Benzene', 'Toluene', 'Xylene']]
y=df['AQI']

# %%
x.head()
# Out:
#        PM2.5        PM10     NO    NO2    NOx        NH3    CO    SO2  \
# 28   83.1300  118.454435   6.93  28.71  33.72  23.848366  1.53  14.89
# 29   79.8400  118.454435  13.85  28.68  41.08  23.848366  1.53  14.89
# 30   94.5200  118.454435  24.39  32.66  52.61  23.848366  1.53  14.89
# 31  135.9900  118.454435  19.71  42.08  38.17  23.848366  1.53  14.89
# 32   79.5075  118.454435  19.71  35.31  72.80  23.848366  1.53  14.89
#
#          O3  Benzene  Toluene    Xylene
# 28  59.7600     0.02     0.00  3.140000
# 29  45.3975     0.04     0.00  4.810000
# 30  45.3975     0.24     0.01  3.588683
# 31  45.3975     0.40     0.04  3.588683
# 32  45.3975     0.46     0.06  3.588683

# %%
y.head()
# Out:
# 28    209.0
# 29    328.0
# 30    208.0
# 31    208.0
# 32    208.0
# Name: AQI, dtype: float64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x,y,test_size=0.2,random_state=70)
print(X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)
# Splitting the data into training and testing data
# Out:
# (19880, 12) (4970, 12) (19880,) (4970,)

# %% [markdown]
# ## Applying an appropiate Regression Algorithm to build

# %% [markdown]
# #### Linear Regression

# %%
model=LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
#Predicting train
train_pred=model.predict(X_train)
#Predicting test
test_pred=model.predict(X_test)

# %%
RMSE_train = np.sqrt(metrics.mean_squared_error(Y_train, train_pred))
RMSE_test = np.sqrt(metrics.mean_squared_error(Y_test, test_pred))
print("RMSE Training Data = ", RMSE_train)
print("RMSE Test Data = ", RMSE_test)
print('-' * 50)
print('R-Squared value on train:', model.score(X_train, Y_train))
print('R-Squared value on test:', model.score(X_test, Y_test))
# Out:
# RMSE Training Data =  51.70703411023219
# RMSE Test Data =  50.98891707971115
# --------------------------------------------------
# R-Squared value on train: 0.6510670631277098
# R-Squared value on test: 0.6561645891946595

# %% [markdown]
# #### K-Nearest Neighbours

# %%
KNN = KNeighborsRegressor()
KNN.fit(X_train, Y_train)
# Out:
# KNeighborsRegressor()

# %%
#Predicting train
train_pred=KNN.predict(X_train)
#Predicting test
test_pred=KNN.predict(X_test)

# %%
RMSE_train = np.sqrt(metrics.mean_squared_error(Y_train, train_pred))
RMSE_test = np.sqrt(metrics.mean_squared_error(Y_test, test_pred))
print("RMSE Training Data = ", RMSE_train)
print("RMSE Test Data = ", RMSE_test)
print('-' * 50)
print('R-Squared value on train:', KNN.score(X_train, Y_train))
print('R-Squared value on test:', KNN.score(X_test, Y_test))
# Out:
# RMSE Training Data =  35.55393018655267
# RMSE Test Data =  42.61508428304119
# --------------------------------------------------
# R-Squared value on train: 0.8350250743661863
# R-Squared value on test: 0.759826145336786

# %% [markdown]
# #### Decision Tree Regression

# %%
DT=DecisionTreeRegressor()
DT.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor()

# %%
#Predicting train
train_pred=DT.predict(X_train)
#Predicting test
test_pred=DT.predict(X_test)

# %%
RMSE_train = np.sqrt(metrics.mean_squared_error(Y_train, train_pred))
RMSE_test = np.sqrt(metrics.mean_squared_error(Y_test, test_pred))
print("RMSE Training Data = ", RMSE_train)
print("RMSE Test Data = ", RMSE_test)
print('-' * 50)
print('R-Squared value on train:', DT.score(X_train, Y_train))
print('R-Squared value on test:', DT.score(X_test, Y_test))
# Out:
# RMSE Training Data =  35.55393018655267
# RMSE Test Data =  42.61508428304119
# --------------------------------------------------
# R-Squared value on train: 0.9991056471481347
# R-Squared value on test: 0.7144463888854515

# %% [markdown]
# #### Random Forest Regression

# %%
RF=RandomForestRegressor()
RF.fit(X_train, Y_train)
# Out:
# RandomForestRegressor()

# %%
#Predicting train
train_pred=RF.predict(X_train)
#Predicting test
test_pred=RF.predict(X_test)

# %%
RMSE_train = np.sqrt(metrics.mean_squared_error(Y_train, train_pred))
RMSE_test = np.sqrt(metrics.mean_squared_error(Y_test, test_pred))
print("RMSE Training Data = ", RMSE_train)
print("RMSE Test Data = ", RMSE_test)
print('-' * 50)
print('R-Squared value on train:', RF.score(X_train, Y_train))
print('R-Squared value on test:', RF.score(X_test, Y_test))
# Out:
# RMSE Training Data =  13.17170118041077
# RMSE Test Data =  33.43355363760797
# --------------------------------------------------
# R-Squared value on train: 0.9773573919047689
# R-Squared value on test: 0.8521694798760229
